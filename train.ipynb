# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense , Dropout
from keras.optimizers import SGD
import random

# %%
# nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sagoi\AppData\Roaming\nltk_data...
# True

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence

# %%
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

# %%
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\sagoi\AppData\Local\Temp/ipykernel_11412/2460837776.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
# Out:
# C:\Users\sagoi\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 2s 5ms/step - loss: 2.2881 - accuracy: 0.1489
# Epoch 2/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1578 - accuracy: 0.1915
# Epoch 3/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0335 - accuracy: 0.3404
# Epoch 4/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0219 - accuracy: 0.2766
# Epoch 5/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8987 - accuracy: 0.3404
# Epoch 6/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.7101 - accuracy: 0.5106
# Epoch 7/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.6667 - accuracy: 0.4468
# Epoch 8/200
# 10/10 [==============================] - 0s 11ms/step - loss: 1.6573 - accuracy: 0.4468
# Epoch 9/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.3907 - accuracy: 0.6383
# Epoch 10/200
# 10/10 [==============================] - 0s 10ms/step - loss: 1.2136 - accuracy: 0.5957
# Epoch 11/200
# 10/10 [==============================] - 0s 16ms/step - loss: 1.2227 - accuracy: 0.6170
# Epoch 12/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.9987 - accuracy: 0.7660
# Epoch 13/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.9379 - accuracy: 0.6809
# Epoch 14/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7811 - accuracy: 0.8298
# Epoch 15/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7765 - accuracy: 0.7234
# Epoch 16/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6644 - accuracy: 0.7447
# Epoch 17/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5541 - accuracy: 0.8511
# Epoch 18/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5927 - accuracy: 0.8298
# Epoch 19/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4853 - accuracy: 0.8936
# Epoch 20/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5417 - accuracy: 0.8298
# Epoch 21/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3900 - accuracy: 0.8511
# Epoch 22/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5219 - accuracy: 0.8085
# Epoch 23/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4136 - accuracy: 0.8936
# Epoch 24/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3388 - accuracy: 0.9362
# Epoch 25/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3752 - accuracy: 0.9149
# Epoch 26/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3962 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2987 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1869 - accuracy: 0.9574
# Epoch 29/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1916 - accuracy: 0.9787
# Epoch 30/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2815 - accuracy: 0.9574
# Epoch 31/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2306 - accuracy: 0.9362
# Epoch 32/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1442 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1640 - accuracy: 0.9787
# Epoch 34/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1663 - accuracy: 0.9362
# Epoch 35/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2559 - accuracy: 0.8936
# Epoch 36/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0909 - accuracy: 1.0000
# Epoch 37/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2243 - accuracy: 0.9149
# Epoch 38/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2001 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1168 - accuracy: 1.0000
# Epoch 40/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1596 - accuracy: 0.9787
# Epoch 41/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1740 - accuracy: 0.9574
# Epoch 42/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1215 - accuracy: 1.0000
# Epoch 43/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1005 - accuracy: 1.0000
# Epoch 44/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1546 - accuracy: 0.9362
# Epoch 45/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1311 - accuracy: 0.9574
# Epoch 46/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1205 - accuracy: 0.9787
# Epoch 47/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1117 - accuracy: 0.9787
# Epoch 48/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1038 - accuracy: 0.9574
# Epoch 49/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1360 - accuracy: 0.9787
# Epoch 50/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1279 - accuracy: 0.9574
# Epoch 51/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0733 - accuracy: 1.0000
# Epoch 52/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0605 - accuracy: 0.9787
# Epoch 53/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1577 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2255 - accuracy: 0.9149
# Epoch 55/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0973 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1297 - accuracy: 0.9574
# Epoch 57/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1536 - accuracy: 0.9574
# Epoch 58/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0990 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0686 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0588 - accuracy: 0.9787
# Epoch 62/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1224 - accuracy: 0.9787
# Epoch 64/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0643 - accuracy: 0.9787
# Epoch 68/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0737 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1167 - accuracy: 0.9574
# Epoch 71/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0921 - accuracy: 0.9787
# Epoch 72/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0757 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1160 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0820 - accuracy: 0.9787
# Epoch 75/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0351 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0689 - accuracy: 0.9787
# Epoch 77/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0784 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0874 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0728 - accuracy: 0.9787
# Epoch 83/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0528 - accuracy: 0.9787
# Epoch 91/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0925 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0837 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0462 - accuracy: 0.9787
# Epoch 99/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0572 - accuracy: 0.9787
# Epoch 102/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 0.9787
# Epoch 106/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1054 - accuracy: 0.9574
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0921 - accuracy: 0.9574
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0564 - accuracy: 0.9787
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0963 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.9787
# Epoch 128/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0504 - accuracy: 0.9787
# Epoch 131/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0523 - accuracy: 0.9787
# Epoch 135/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9787
# Epoch 138/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9787
# Epoch 141/200
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0411 - accuracy: 0.9787
# Epoch 143/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0710 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0340 - accuracy: 0.9787
# Epoch 159/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9574
# Epoch 162/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0417 - accuracy: 0.9787
# Epoch 164/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9787
# Epoch 172/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0328 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0476 - accuracy: 0.9787
# Epoch 176/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 0.9787
# Epoch 179/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0549 - accuracy: 0.9574
# Epoch 180/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0299 - accuracy: 0.9787
# Epoch 181/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1019 - accuracy: 0.9574
# Epoch 183/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0342 - accuracy: 0.9787
# Epoch 185/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0355 - accuracy: 0.9787
# Epoch 186/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0411 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9787
# Epoch 190/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 0.9787
# Epoch 193/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0646 - accuracy: 0.9787
# Epoch 196/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000

# %%
print("model created")
# Out:
# model created
